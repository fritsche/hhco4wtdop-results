# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

df = pd.read_csv("WindTurbineDesignRawHypervolumes.csv")
df = df[['NSGAIII', 'ThetaDEA', 'HHLA', 'CHHCO', 'SPEA2', 'NSGAII', 'SPEA2SDE', 'MOMBI2', 'MOEAD', 'HypE', 'CMOEADD']]
f = plt.figure()
plt.tight_layout()
ax = f.gca()
df.boxplot(ax=ax, showfliers=False)
ax.set_xticklabels(['NSGA-III', 'ThetaDEA', 'HH-LA', 'HH-CO', 'SPEA2', 'NSGA-II', 'SPEA2SDE', 'MOMBI2', 'MOEA/D', 'HypE', 'MOEA/DD'], rotation=45)
plt.ylabel("Hypervolume")
plt.tight_layout()
plt.savefig("hvboxplot.pdf")
