# %%
# imports and configs

import pandas as pd
import numpy as np
import matplotlib
matplotlib.use
import matplotlib.pyplot as plt
# plt.style.use('ggplot')
plt.style.use('seaborn-colorblind')
import matplotlib.ticker as mtick
from matplotlib import rc
# rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)


df = pd.read_csv("WindTurbineDesignRawHypervolumes.csv")
df = df[['NSGAIII','CHHCO','HHLA','NSGAII','SPEA2','ThetaDEA','SPEA2SDE','MOMBI2','MOEAD','HypE','CMOEADD']]
f = plt.figure()
plt.tight_layout()
ax = f.gca()
df.boxplot(ax=ax, showfliers=False)
ax.set_xticklabels(['NSGA-III','HH-CO','HH-LA','NSGA-II','SPEA2','ThetaDEA','SPEA2SDE','MOMBI2','MOEA/D','HypE','MOEA/DD'], rotation=45)
plt.ylabel("Hypervolume", fontsize=14)
plt.tight_layout()
plt.savefig("hvboxplot.pdf")
