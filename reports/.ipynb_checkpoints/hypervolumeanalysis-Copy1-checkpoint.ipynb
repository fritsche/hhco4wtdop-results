# %%
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib
matplotlib.use
import matplotlib.pyplot as plt
plt.style.use('seaborn-muted')


# load data
df = pd.read_csv('WindTurbineDesignHypervolumeMedianRun.csv')
dfmax = df.iloc[[-1]]
dfmaxt = dfmax.transpose()
dfmaxt.columns = ['median']
dfmaxt = dfmaxt.drop('FE', axis=0)

dfbest = pd.read_csv('WindTurbineDesignHypervolumeBestRun.csv')
dfmaxbest = dfbest.iloc[[-1]]
dfmaxbest = dfmaxbest.transpose()
dfmaxbest.columns = ['max']
dfmaxbest = dfmaxbest.drop('FE', axis=0)

labels={
    "NSGAIII": "NSGA-III",
    "SPEA2SDE": "SPEA2SDE",
    "SPEA2": "SPEA2",
    "CMOMBI2": "MOMBI2",
    "ThetaDEA": "ThetaDEA",
    "CMOEAD": "MOEA/D",
    "NSGAII": "NSGA-II",
    "HypE": "HypE",
    "CHHCO": "HH-CO",
    "HHCORandom": "HHCO-rand"
}


def plot_hypervolume(algs, offsets):
    f = plt.figure() # figsize=(12, 8))
#     plt.subplots_adjust(right=0.85)
    ax = f.gca()
#     ax.spines['top'].set_visible(False)
#     ax.spines['bottom'].set_visible(False)
#     ax.spines['right'].set_visible(False)
#     ax.spines['left'].set_visible(False)

    colors={
        "NSGAIII": "tab:blue",
        "SPEA2SDE": "tab:orange",
        "SPEA2": "tab:green",
        "CMOMBI2": "tab:red",
        "ThetaDEA": "tab:purple",
        "CMOEAD": "tab:brown",
        "NSGAII": "tab:pink",
        "HypE": "tab:grey",
        "CHHCO": "k",
    }

    styles={
        "NSGAIII": "-",
        "SPEA2SDE": "-",
        "SPEA2": "-",
        "CMOMBI2": "-",
        "ThetaDEA": "-",
        "CMOEAD": "-",
        "NSGAII": "-",
        "HypE": "-",
        "CHHCO": "--",
    }

    for alg in algs:
        df.plot(x="FE", y=alg, ax=f.gca(), legend=False, color=colors[alg], style=styles[alg])
#         plt.text(9870, dfmax[alg]+offset[alg], labels[alg], color=colors[alg], fontsize=14) #, weight='bold')
    plt.xlabel("Fitness Evaluations")#, fontsize=14)
    plt.ylabel("Hypervolume")#, fontsize=14)
    ax.grid(True, ls='--')
#     ax.tick_params(axis='both', which='both', # labelsize=14,
#                bottom=False, top=False, labelbottom=True,
#                left=False, right=False, labelleft=True)
    ax.set_xlim(0, 9870)
    ax.legend()
    plt.show()
    return f

# %%
# all MOEAs and HHs

offset={
    "NSGAIII":   0.19,
    "SPEA2SDE":  0.04,
    "SPEA2":     0.0,
    "CMOMBI2":   -0.11,
    "ThetaDEA":  0.05,
    "CMOEAD":    -0.19,
    "NSGAII":    -0.11,
    "HypE":      0.0,
#     "CMOEADD":   0.0,
    "CHHCO":     0.12,
}

algs=["HypE","NSGAII","CMOEAD","ThetaDEA","CMOMBI2","SPEA2","SPEA2SDE","NSGAIII","CHHCO"]
fig = plot_hypervolume(algs, offset)
fig.savefig("hypervolume.pdf")

# %%
dfmaxbest.index.name = 'alg'
dfmaxbest.reset_index(inplace=True)

dfmaxt.index.name = 'alg'
dfmaxt.reset_index(inplace=True)

# %%
dfoverall = dfmaxbest.merge(dfmaxt, on = ['alg'], how='inner')

dfoverall.sort_values(by=['alg'], inplace=True, ascending=True)

dfoverall = dfoverall.set_index("alg")

display(dfoverall)

# remove column max and row CHHCO
dfmedian = dfoverall.drop('max', axis=1).drop('CHHCO', axis=0)

1-(dfmedian.mean()/0.657381)
# Out:
#                max    median
# alg
# CHHCO     0.678832  4.826766
# CMOEAD    0.562005  4.349473
# CMOMBI2   0.634919  4.414812
# HypE      0.470731  3.410988
# NSGAII    0.668537  4.583595
# NSGAIII   0.693573  4.905625
# SPEA2     0.664635  0.583742
# SPEA2SDE  0.663690  4.584765
# ThetaDEA  0.668918  4.739181
# median   -5.003402
# dtype: float64

# %%
dfoverall = dfoverall.rename({"CHHCO": "HH-CO", "CMOEAD": "MOEA/D", "CMOMBI2": "MOMBI2", "NSGAII": "NSGA-II", "NSGAIII": "NSGA-III"}, axis="index")
dfoverall.sort_values(by=['alg'], inplace=True, ascending=True)
display(dfoverall)

# Hypervolume
ax = dfoverall.plot.bar(y='max', color='lightsteelblue', label="Max")

for i in ax.patches:
    ax.text(i.get_x()+0.05, i.get_height()+.07, \
            round(i.get_height(), 2), color='dimgray', rotation=67.5)

ax = dfoverall.plot.bar(y='median', color='steelblue', ax=ax, label="Median")

for i in ax.patches[len(ax.patches)//2:]:
    ax.text(i.get_x()+0.05, i.get_height()-0.04, \
            round(i.get_height(), 2), color='whitesmoke', rotation=67.5)

ax.set_ylabel("Hypervolume")
ax.set_xlabel("")
ax.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower right', ncol=2)

plt.setp(ax.get_xticklabels(), rotation=67.5)
ax.set_ylim(0,0.8)
fig = ax.get_figure()
plt.subplots_adjust(left=0.15)
fig.savefig("hvanalysis.pdf", bbox_inches='tight')
# Out:
#                max    median
# alg
# HH-CO     0.678832  4.826766
# HypE      0.470731  3.410988
# MOEA/D    0.562005  4.349473
# MOMBI2    0.634919  4.414812
# NSGA-II   0.668537  4.583595
# NSGA-III  0.693573  4.905625
# SPEA2     0.664635  0.583742
# SPEA2SDE  0.663690  4.584765
# ThetaDEA  0.668918  4.739181

# %%
# MOEAs

offset={
    "NSGAIII": 0.0,
    "SPEA2SDE": 0.0,
    "SPEA2": 0.01,
    "CMOMBI2": -0.01,
    "ThetaDEA": -0.01,
    "CMOEAD": 0.00,
    "NSGAII": 0.00,
    "HypE": 0.00,
}


plot_hypervolume(["HypE","NSGAII","CMOEAD","ThetaDEA","CMOMBI2","SPEA2","SPEA2SDE","NSGAIII"], offset)

# %%
# best MOEAs and HHs

offset={
    "NSGAIII": -0.02,
    "SPEA2SDE": -0.01,
    "SPEA2": 0.00,
    "CMOMBI2": 0.0,
    "ThetaDEA": 0.0,
    "CMOEAD": 0.00,
    "NSGAII": 0.00,
    "HypE": 0.00,
    "CMOEADD": 0.00,
    "CHHCO": 0.00,
}


plot_hypervolume(["SPEA2", "SPEA2SDE", "NSGAIII", "CHHCO"], offset)
